# %% [markdown]
# # Probabilidad:
#
# El concepto que estaremos utilizando más en ciencia de datos es la de probabilidad frecuentista.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Un modelo estadístico asume ciertas distribuciones en los datos.
#
# Un modelo de machine learning no asume distribuciones

# %% [markdown]
# # Distribuciones de probabilidad
#
# Histogramas: Ayuda a ver la distribución de la variable

# %% [markdown]
# ## ¿Qué es asimetría?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ¿Qué es curtosis?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Distribución normal:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Teorema de bayes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
